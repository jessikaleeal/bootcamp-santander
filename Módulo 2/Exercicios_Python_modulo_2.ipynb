# %% [markdown]
# 1. Faça um programa que olhe todos os itens de uma lista e diga quantos deles
# são pares.

# %%
contador = 0
for numero in range(100):
  if numero % 2 == 0:
    contador = contador + 1
if contador == 0:
  print('Lista não contém números pares')
else:
  print(f'A lista possui {contador} números pares')
# Out:
# A lista possui 50 números pares

# %% [markdown]
# 2. Faça um programa que peça para o usuário digitar uma palavra e imprima
# cada letra em uma linha

# %%
palavra = input('Digite uma palavra: ')
palavra_linha = palavra.strip()

for index in range(len(palavra_linha)):
  print(palavra[index])
# Out:
# Digite uma palavra: Deus
# D
# e
# u
# s

# %% [markdown]
# 3. Faça uma função que recebe duas listas e retorna a soma item a item dessas
# listas.
# Exemplo: Se a função receber as listas [1,4,3] e [3,5,1], então a função deve
# retornar [1+3, 4+5, 3+1] = [4, 9, 4].

# %%
def soma_lista(lista1, lista2):
  resultado = []
  for x, y in enumerate(lista1):
    resultado.append(y + lista2[x])
  return resultado

soma_lista([1,4,3], [3,5,1])
# Out:
# [4, 9, 4]

# %% [markdown]
# 4. Crie um dicionário cujas chaves são os meses do ano e os valores são a
# duração (em dias) de cada mês.

# %%
meses = {
    'Janeiro' = 
    'Fevereiro' = 
    'Março' =
    'Abril' = 
    'Maio' = 
    'Junho' =
    'Julho' = 
    'Agosto' = 
    'Setembro' =
    'Outubro' = 
    'Novembro' =
    'Dezembro' = 
}

# %% [markdown]
# 5. Imprima as chaves seguidas dos seus valores para dicionário criado no
# exercício anterior.
# Exemplo:
# Janeiro - 31
# Fevereiro - 28
# Março - 31
# Etc...
